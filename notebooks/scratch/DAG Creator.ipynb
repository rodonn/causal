# %%
import graphviz as gr

# %%
g = gr.Digraph()
g.edge('A','B')
g.edge('B','C')
g.edge('C','A')
g.edge('C','D')
g.edge('D','B')
g.edge('D','A')
g.render('dags/cyclic', format='png')
g

# %%
g = gr.Digraph()
g.edge('A','B')
g.edge('B','C')
g.edge('A','C')
g.edge('C','D')
g.edge('B','D')
g.edge('A','D')
g.render('dags/acyclic', format='png')
g

# %%
g = gr.Digraph()
g.edge('Parent 1','Child 1')
g.edge('Parent 1','Child 2')
g.edge('Parent 2','Child 1')
g.edge('Parent 3','Child 1')
g.edge('Parent 3','Child 2')
g.render('dags/parents_children', format='png')
g

# %%
g = gr.Digraph()
g.attr(rankdir='LR')
g.edge('Time','Rooster crows')
g.edge('Time','Sun rises')
g.render('dags/time', format='png')
g

# %%
g = gr.Digraph()
g.attr(rankdir='LR')
g.edge('GPA', 'Accepted at Harvard')
g.edge('SAT', 'Accepted at Harvard')
g.render('dags/gpa_sat', format='png')
g

# %%
g = gr.Digraph()
g.attr(rankdir='LR')
g.edge('Age', 'Walking Speed')
g.edge('Age', 'Mortality')
g.edge('Walking Speed', 'Mortality')
g.edge('Health', 'Mortality')
g.edge('Health', 'Walking Speed')
g.render('dags/age_walking_speed', format='png')
g

# %%
g = gr.Digraph()
g.attr(rankdir='LR')
g.edge('Father education', 'education')
g.edge('Mother education', 'education')
g.edge('intelligence', 'education')
g.edge('intelligence', 'income')
g.edge('education', 'income')
g.edge('education', 'job industry')
g.edge('education', 'read WSJ')
g.edge('job industry', 'income')
g.edge('job industry', 'read WSJ')
g.edge('market conditions', 'income')
g.render('dags/education_income', format='png')
g

# %%
g = gr.Digraph()
g.edge('gender', 'take medicine')
g.edge('gender', 'heart attack')
g.edge('take medicine', 'heart attack')
g.render('dags/ggb_gender', format='png')
g

# %%
g = gr.Digraph()
g.edge('take medicine', 'headache')
g.edge('take medicine', 'heart attack')
g.edge('headache', 'heart attack')
g.render('dags/ggb_headache', format='png')
g

# %%
g = gr.Digraph()
g.edge('take medicine', 'headache')
g.edge('take medicine', 'heart attack')
g.edge('health condition', 'headache')
g.edge('health condition', 'heart attack')
g.render('dags/ggb_headache_2', format='png')
g

# %%
g = gr.Digraph()
g.attr(rankdir='LR')
g.edge('Confounder', 'Treatment')
g.edge('Confounder', 'Outcome')
g.edge('Treatment', 'Outcome')
g.edge('Treatment', 'Mediator')
g.edge('Mediator', 'Outcome')
g.edge('Treatment', 'Collider')
g.edge('Outcome', 'Collider')
g.render('dags/base_types', format='png')
g

# %%
g = gr.Digraph()
g.attr(rankdir='LR')
g.edge('Confounder', 'Treatment')
g.edge('Confounder', 'Outcome')
g.edge('Treatment', 'Outcome')
g.edge('Treatment', 'Mediator')
g.edge('Mediator', 'Outcome')
g.edge('Treatment', 'Collider')
g.edge('Outcome', 'Collider')
g.node('Confounder', color='grey', style='filled')
g.node('Mediator', color='red')
g.node('Collider', color='red')
g.render('dags/base_types_colors', format='png')
g

# %%
g = gr.Digraph()
g.edge('Confounder', 'Treatment')
g.edge('Confounder', 'Outcome')
g.edge('Instrument', 'Treatment')
g.edge('Treatment', 'Outcome')
g.edge('Treatment', 'Mediator')
g.edge('Mediator', 'Outcome')
g.edge('Treatment', 'Collider')
g.edge('Outcome\nPredictor', 'Outcome')
g.edge('Outcome', 'Collider')
g.node('Confounder', color='green', style='filled')
g.node('Outcome\nPredictor', color='cyan', style='filled')
g.node('Instrument', color='orange', style='filled')
g.node('Mediator', color='red', style='filled')
g.node('Collider', color='red', style='filled')
g.render('dags/base_types_expanded', format='png')
g

# %%
g = gr.Digraph()
g.edge('soil', 'plant growth')
g.edge('sun', 'plant growth')
g.edge('drainage', 'plant growth')
g.edge('soil', 'fertilizer')
g.edge('sun', 'fertilizer')
g.edge('drainage', 'fertilizer')
g.edge('fertilizer', 'plant growth')
g.render('dags/soil_observational', format='png')
g

# %%
g = gr.Digraph()
g.edge('soil', 'plant growth')
g.edge('sun', 'plant growth')
g.edge('drainage', 'plant growth')
g.edge('coin flip', 'fertilizer')
g.edge('fertilizer', 'plant growth')
g.render('dags/soil_experimental', format='png')
g

# %%
g = gr.Digraph()
g.edge('gender', 'member')
g.edge('age', 'member')
g.edge('income', 'member')
g.edge('location', 'member')
g.edge('gender', 'spending')
g.edge('age', 'spending')
g.edge('income', 'spending')
g.edge('location', 'spending')
g.edge('member', 'spending')
g.edge('member', 'number of purchases')
g.edge('number of purchases', 'spending')
g.render('dags/membership1', format='png')
g

# %%
g = gr.Digraph()
g.edge('expected spending', 'member')
g.edge('expected spending', 'spending')
g.edge('member', 'spending')
g.render('dags/membership2', format='png')
g

# %%
g = gr.Digraph()
g.edge('Confounder', 'Treatment')
g.edge('Confounder', 'Outcome')
g.edge('Treatment', 'Outcome')
g.render('dags/confounder', format='png')
g

# %%
g = gr.Digraph()
g.edge('X', 'T')
g.edge('X', 'Y')
g.edge('T', 'Y')
g.render('dags/confounder_letters', format='png')
g

# %%
g = gr.Digraph()
g.edge('X', 'T')
g.edge('X', 'Y')
g.edge('T', 'Y')
g.render('dags/xyt_1', format='png')
g

# %%
g = gr.Digraph()
g.edge('X', 'Y')
g.edge('T', 'Y')
g.render('dags/xyt_2', format='png')
g

# %%
g = gr.Digraph()
g.edge('X', 'T')
g.edge('T', 'Y')
g.render('dags/xyt_3', format='png')
g

# %%
g = gr.Digraph()
g.edge('U', 'T')
g.edge('U', 'X')
g.edge('X', 'Y')
g.edge('T', 'Y')
g.render('dags/xyt_4', format='png')
g

# %%
g = gr.Digraph()
g.edge('X1', 'T')
g.edge('X1', 'Y')
g.edge('X2', 'T')
g.edge('X2', 'Y')
g.edge('X3', 'T')
g.edge('X3', 'Y')
g.edge('T', 'Y')
g.render('dags/ps_score_1', format='png')
g

# %%
g = gr.Digraph()
g.edge('X1', 'P(T=1)')
g.edge('X1', 'Y')
g.edge('X2', 'P(T=1)')
g.edge('X2', 'Y')
g.edge('X3', 'P(T=1)')
g.edge('X3', 'Y')
g.edge('P(T=1)', 'T')
g.edge('T', 'Y')
g.render('dags/ps_score_2', format='png')
g

# %%
g = gr.Digraph()
g.edge('X', 'P(T=1)')
g.edge('X', 'Y')
g.edge('Z', 'P(T=1)')
g.edge('P(T=1)', 'T')
g.edge('T', 'Y')
g.node('X', color='green', style='filled')
g.node('Z', color='orange', style='filled')
g.render('dags/ps_score_3', format='png')
g

# %%
g = gr.Digraph()
g.edge('Gender', 'P(Take Medicine=1)')
g.edge('Gender', 'Heart Attack')
g.edge('Coin Flip', 'P(Take Medicine=1)')
g.edge('P(Take Medicine=1)', 'T')
g.edge('Take Medicine', 'Heart Attack')
g.node('Gender', color='green', style='filled')
g.node('Z', color='red', style='filled')
g.render('dags/ps_score_3', format='png')
g

# %%
g = gr.Digraph()
g.edge('Customer Type (unobserved)', 'Order Size')
g.edge('Customer Type (unobserved)', 'Restaurant')
g.edge('Customer Type (unobserved)', 'Customer Tenure')
g.edge('Customer Type (unobserved)', 'MAO')
g.edge('Order Size', 'Late Delivery')
g.edge('Restaurant', 'Late Delivery')
g.edge('Location', 'Late Delivery')
g.edge('Location', 'MAO')
g.edge('Customer Tenure', 'Late Delivery')
g.edge('Customer Tenure', 'MAO')
g.edge('Late Delivery', 'Customer Satisfaction')
g.edge('Customer Satisfaction', 'MAO')
g.edge('Late Delivery', 'MAO')
g.render('dags/late_delivery', format='png')
g

# %%
g = gr.Digraph()
g.edge('X', 'Y0')
g.edge('X', 'Y1')
g.edge('T', 'Y1')
g.render('dags/event_study', format='png')
g

# %%
g = gr.Digraph()
g.edge('U', 'Y0')
g.edge('U', 'Y1')
g.edge('X0', 'Y0')
g.edge('X1', 'Y1')
g.edge('T', 'Y1')
#g.render('dags/event_study', format='png')
g

# %%
g = gr.Digraph()
g.edge('X0', 'Y0')
g.edge('X1', 'Y1')
g.edge('X2', 'Y2')
g.edge('X3', 'Y3')
g.edge('X4', 'Y4')
g.edge('T', 'Y4')
g.edge('Y0', 'Y1')
g.edge('Y1', 'Y2')
g.edge('Y2', 'Y3')
g.edge('Y3', 'Y4')
g.render('dags/time_series', format='png')
g
